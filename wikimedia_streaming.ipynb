# %%
import json
import time
import requests
from kafka import KafkaProducer

STREAM_URL = "https://stream.wikimedia.org/v2/stream/recentchange"
TOPIC = "wikimedia_recentchange"

producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

resp = requests.get(STREAM_URL, stream=True, headers={"User-Agent": "spark-streaming-training/1.0"})
resp.raise_for_status()

count = 0
for line in resp.iter_lines():
    if not line:
        continue


    if line.startswith(b"data: "):
        data = line[len(b"data: "):]
        try:
            event = json.loads(data.decode("utf-8"))
            producer.send(TOPIC, event)
            count += 1

            if count % 20 == 0:
                print("sent", count, "events")

            if count >= 200:
                break
        except Exception:
            pass

producer.flush()
producer.close()
print("DONE. sent total:", count)
# Out:
# sent 20 events
# sent 40 events
# sent 60 events
# sent 80 events
# sent 100 events
# sent 120 events
# sent 140 events
# sent 160 events
# sent 180 events
# sent 200 events
# DONE. sent total: 200

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("WikimediaKafkaToConsole").getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/18 13:16:00 WARN Utils: Your hostname, Izabellas-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.166.165 instead (on interface en0)
# 26/01/18 13:16:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/opt/anaconda3/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/izabellasvavolya/.ivy2.5.2/cache
# The jars for the packages stored in: /Users/izabellasvavolya/.ivy2.5.2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.13 added as a dependency
# org.apache.spark#spark-token-provider-kafka-0-10_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3545ba84-4b6d-40a9-a7f1-6e0950d7d021;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.1 in central
# 	found org.apache.kafka#kafka-clients;3.9.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.8 in central
# 	found org.slf4j#slf4j-api;2.0.17 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.4.2 in central
# 	found org.apache.hadoop#hadoop-client-api;3.4.2 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found org.apache.commons#commons-pool2;2.12.1 in central
# :: resolution report :: resolve 534ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	org.apache.commons#commons-pool2;2.12.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.4.2 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.4.2 from central in [default]
# 	org.apache.kafka#kafka-clients;3.9.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.13;4.1.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.13;4.1.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.17 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.8 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3545ba84-4b6d-40a9-a7f1-6e0950d7d021
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/9ms)
# 26/01/18 13:16:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
from pyspark.sql.functions import col

df = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "wikimedia_recentchange") \
    .option("startingOffsets", "earliest") \
    .load()

out = df.select(col("value").cast("string").alias("value"))

q = out.writeStream \
    .format("console") \
    .outputMode("append") \
    .option("truncate", "false") \
    .start()
# Out:
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Duplicate", "request_id": "1eeb1e6d-576a-4f70-b983-d6794eaea15f", "id": "0ffbd970-d4e9-4604-8a6e-07a6ac999da1", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.818Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074938}, "id": 3159709471, "type": "categorize", "namespace": 14, "title": "Category:Duplicate", "title_url": "https://commons.wikimedia.org/wiki/Category:Duplicate", "comment": "[[:File:St. Andrews, Manitoba - panoramio (94).jpg]] added to category", "timestamp": 1768734939, "user": "Gauss", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247057&oldid=1140553641&rcid=3159709471", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:St._Andrews,_Manitoba_-_panoramio_(94).jpg\" title=\"File:St. Andrews, Manitoba - panoramio (94).jpg\">File:St. Andrews, Manitoba - panoramio (94).jpg</a> added to category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/File:2018_FEMA_PuertoRico_20QKF3804_RGB.tif", "request_id": "90bbfb6a-7eb9-4997-8537-0819d192a53a", "id": "6120e553-12c4-4049-9279-5936611cabc7", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.822Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074939}, "id": 3159709470, "type": "edit", "namespace": 6, "title": "File:2018 FEMA PuertoRico 20QKF3804 RGB.tif", "title_url": "https://commons.wikimedia.org/wiki/File:2018_FEMA_PuertoRico_20QKF3804_RGB.tif", "comment": "Doing 1 replacements.", "timestamp": 1768734940, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247073&oldid=1079286162&rcid=3159709470", "minor": false, "patrolled": true, "length": {"old": 2777, "new": 2796}, "revision": {"old": 1079286162, "new": 1149247073}, "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "Doing 1 replacements."}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "request_id": "2e61cab1-7f99-4cba-b299-3c5601206c8d", "id": "0aa57fc3-6522-4c14-8f0a-784c006e1286", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.832Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074940}, "id": 3159709468, "type": "categorize", "namespace": 14, "title": "Category:Files from the United States Army uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3708 RGB.tif]] added to category", "timestamp": 1768734939, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247067&oldid=1087617563&rcid=3159709468", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3708_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3708 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3708 RGB.tif</a> added to category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "request_id": "9278006a-310d-4f62-9736-cd3a08c5b749", "id": "c6cb959c-bc51-4600-9bfc-0dc7f480f6fc", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.804Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074941}, "id": 3159709467, "type": "categorize", "namespace": 14, "title": "Category:Files from the United States Army uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3800 RGB.tif]] added to category", "timestamp": 1768734939, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247066&oldid=1107311547&rcid=3159709467", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3800_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3800 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3800 RGB.tif</a> added to category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Images_from_the_Earth_Science_and_Remote_Sensing_Unit,_Lyndon_B._Johnson_Space_Center", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "5ab8ecd9-93ac-41d7-819b-bb8c28de4119", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.849Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074942}, "id": 3159709457, "type": "categorize", "namespace": 14, "title": "Category:Images from the Earth Science and Remote Sensing Unit, Lyndon B. Johnson Space Center", "title_url": "https://commons.wikimedia.org/wiki/Category:Images_from_the_Earth_Science_and_Remote_Sensing_Unit,_Lyndon_B._Johnson_Space_Center", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709457", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                               |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_USDA_uploaded_by_PantheraLeo1359531", "request_id": "2e61cab1-7f99-4cba-b299-3c5601206c8d", "id": "5e31db37-e9c2-44bc-aef1-a248fad7ff74", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.852Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074943}, "id": 3159709478, "type": "categorize", "namespace": 14, "title": "Category:Files from USDA uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_USDA_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3708 RGB.tif]] removed from category", "timestamp": 1768734939, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247067&oldid=1087617563&rcid=3159709478", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3708_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3708 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3708 RGB.tif</a> removed from category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_USDA_uploaded_by_PantheraLeo1359531", "request_id": "9278006a-310d-4f62-9736-cd3a08c5b749", "id": "197edf62-4501-496a-8d7e-e4cf3d71dee3", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.850Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074944}, "id": 3159709473, "type": "categorize", "namespace": 14, "title": "Category:Files from USDA uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_USDA_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3800 RGB.tif]] removed from category", "timestamp": 1768734939, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247066&oldid=1107311547&rcid=3159709473", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3800_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3800 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3800 RGB.tif</a> removed from category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://meta.wikimedia.org/wiki/User:%EA%B8%B0%EB%82%98%E3%85%8F%E3%84%B4/sandbox", "request_id": "70f0d69b-c2d9-4175-bf3e-dcfa55525f92", "id": "50936fb4-d5b8-455c-bf1d-85ce1fcbdf47", "domain": "meta.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.887Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074945}, "id": 38138435, "type": "edit", "namespace": 2, "title": "User:\uae30\ub098\u314f\u3134/sandbox", "title_url": "https://meta.wikimedia.org/wiki/User:%EA%B8%B0%EB%82%98%E3%85%8F%E3%84%B4/sandbox", "comment": "", "timestamp": 1768734940, "user": "\uae30\ub098\u314f\u3134", "bot": false, "notify_url": "https://meta.wikimedia.org/w/index.php?diff=29948369&oldid=29889157&rcid=38138435", "minor": false, "patrolled": true, "length": {"old": 961, "new": 973}, "revision": {"old": 29889157, "new": 29948369}, "server_url": "https://meta.wikimedia.org", "server_name": "meta.wikimedia.org", "server_script_path": "/w", "wiki": "metawiki", "parsedcomment": ""}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Pages_with_local_camera_coordinates_and_missing_SDC_coordinates", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "57c8d7ee-1cf0-4b37-b3e7-2f1d2eb4e7a2", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.888Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074946}, "id": 3159709458, "type": "categorize", "namespace": 14, "title": "Category:Pages with local camera coordinates and missing SDC coordinates", "title_url": "https://commons.wikimedia.org/wiki/Category:Pages_with_local_camera_coordinates_and_missing_SDC_coordinates", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709458", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                                                                                                 |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/File:2018_FEMA_PuertoRico_20QKF3807_RGB.tif", "request_id": "8f4bff5b-8741-4025-aba2-99807b9246d8", "id": "afe33ab7-71f4-4d70-b277-6f169c652076", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.900Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074947}, "id": 3159709482, "type": "edit", "namespace": 6, "title": "File:2018 FEMA PuertoRico 20QKF3807 RGB.tif", "title_url": "https://commons.wikimedia.org/wiki/File:2018_FEMA_PuertoRico_20QKF3807_RGB.tif", "comment": "Doing 1 replacements.", "timestamp": 1768734940, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247074&oldid=1131284886&rcid=3159709482", "minor": false, "patrolled": true, "length": {"old": 3828, "new": 3847}, "revision": {"old": 1131284886, "new": 1149247074}, "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "Doing 1 replacements."}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Media_with_erroneous_locations", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "69bb51b9-270f-48e2-b52d-ed3537f24e23", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.907Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074948}, "id": 3159709459, "type": "categorize", "namespace": 14, "title": "Category:Media with erroneous locations", "title_url": "https://commons.wikimedia.org/wiki/Category:Media_with_erroneous_locations", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709459", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                                                                                                                                                                                                    |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Pages_with_local_object_coordinates_and_missing_SDC_coordinates", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "d7c13ea5-3d3e-43ac-99bc-dc07899665e2", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.957Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074949}, "id": 3159709460, "type": "categorize", "namespace": 14, "title": "Category:Pages with local object coordinates and missing SDC coordinates", "title_url": "https://commons.wikimedia.org/wiki/Category:Pages_with_local_object_coordinates_and_missing_SDC_coordinates", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709460", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                                                                                                 |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_NASA_with_known_IDs", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "124b2bd1-fa48-4d25-8a6a-0580f7887ba5", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.979Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074950}, "id": 3159709461, "type": "categorize", "namespace": 14, "title": "Category:Files from NASA with known IDs", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_NASA_with_known_IDs", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709461", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                                                                                                                                                                                                    |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "request_id": "aa6c2446-f9ab-4b28-9295-659ee02ff588", "id": "3c14731c-293e-4a19-a3fc-91c178630885", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:40.995Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074951}, "id": 3159709483, "type": "categorize", "namespace": 14, "title": "Category:Files from the United States Army uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3801 RGB.tif]] added to category", "timestamp": 1768734939, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247069&oldid=1098491203&rcid=3159709483", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3801_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3801 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3801 RGB.tif</a> added to category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Extracted_images", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "5f2fbfa8-4ae8-4f06-8dba-f115e0cb690b", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:41.010Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074952}, "id": 3159709466, "type": "categorize", "namespace": 14, "title": "Category:Extracted images", "title_url": "https://commons.wikimedia.org/wiki/Category:Extracted_images", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709466", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                                                                                                                                                                                                                                              |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_USDA_uploaded_by_PantheraLeo1359531", "request_id": "aa6c2446-f9ab-4b28-9295-659ee02ff588", "id": "0ba6d253-e9d5-41ab-99d3-6aabe1b06797", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:41.023Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074953}, "id": 3159709484, "type": "categorize", "namespace": 14, "title": "Category:Files from USDA uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_USDA_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3801 RGB.tif]] removed from category", "timestamp": 1768734939, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247069&oldid=1098491203&rcid=3159709484", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3801_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3801 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3801 RGB.tif</a> removed from category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:1938_%D0%B3%D0%BE%D0%B4_%D0%B2_%D0%9B%D0%BE%D0%BD%D0%B4%D0%BE%D0%BD%D0%B5", "request_id": "03765aa8-b90c-4bf9-9c8b-267c72e660c4", "id": "41fb53a4-4635-4d8d-91e6-4da9b807a82c", "domain": "ru.wikipedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:41.001Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074954}, "id": 527348556, "type": "edit", "namespace": 14, "title": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f:1938 \u0433\u043e\u0434 \u0432 \u041b\u043e\u043d\u0434\u043e\u043d\u0435", "title_url": "https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:1938_%D0%B3%D0%BE%D0%B4_%D0%B2_%D0%9B%D0%BE%D0%BD%D0%B4%D0%BE%D0%BD%D0%B5", "comment": "\u0417\u0430\u043c\u0435\u043d\u0430 \u0441\u043e\u0434\u0435\u0440\u0436\u0438\u043c\u043e\u0433\u043e \u0441\u0442\u0440\u0430\u043d\u0438\u0446\u044b \u043d\u0430 \u0435\u0434\u0438\u043d\u043e\u043e\u0431\u0440\u0430\u0437\u043d\u043e\u0435 \u043d\u0430\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435: {{\u0413\u043e\u0434\u044b \u0432 \u0433\u043e\u0440\u043e\u0434\u0435}}", "timestamp": 1768734939, "user": "Sldst-bot", "bot": true, "notify_url": "https://ru.wikipedia.org/w/index.php?diff=151231870&oldid=112132034", "minor": false, "length": {"old": 30, "new": 28}, "revision": {"old": 112132034, "new": 151231870}, "server_url": "https://ru.wikipedia.org", "server_name": "ru.wikipedia.org", "server_script_path": "/w", "wiki": "ruwiki", "parsedcomment": "\u0417\u0430\u043c\u0435\u043d\u0430 \u0441\u043e\u0434\u0435\u0440\u0436\u0438\u043c\u043e\u0433\u043e \u0441\u0442\u0440\u0430\u043d\u0438\u0446\u044b \u043d\u0430 \u0435\u0434\u0438\u043d\u043e\u043e\u0431\u0440\u0430\u0437\u043d\u043e\u0435 \u043d\u0430\u043f\u043e\u043b\u043d\u0435\u043d\u0438\u0435: {{\u0413\u043e\u0434\u044b \u0432 \u0433\u043e\u0440\u043e\u0434\u0435}}"}|
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:PD_NASA", "request_id": "04aee3c3-ae16-461a-b524-445e4da04e98", "id": "a5767472-7125-4bd7-a73b-485dde19372b", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:41.034Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074955}, "id": 3159709472, "type": "categorize", "namespace": 14, "title": "Category:PD NASA", "title_url": "https://commons.wikimedia.org/wiki/Category:PD_NASA", "comment": "[[:File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg]] added to category", "timestamp": 1768734938, "user": "LudwigSebastianMicheler", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247048&oldid=0&rcid=3159709472", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:ISS065-E-30070_-_View_of_Argentina_-_Southern_Patagonian_Ice_Field_-_Glaciar_Bertachi_-_Glaciar_Cono_-_Cerro_Tosello_-_Upsala_Glacier_terminus_-_Lake_Argentino_(Brazo_Upsala)_(cropped).jpg\" title=\"File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg\">File:ISS065-E-30070 - View of Argentina - Southern Patagonian Ice Field - Glaciar Bertachi - Glaciar Cono - Cerro Tosello - Upsala Glacier terminus - Lake Argentino (Brazo Upsala) (cropped).jpg</a> added to category"}                                                                                                                                                                                                                                                                                         |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://meta.wikimedia.org/wiki/User:153.131.213.26", "request_id": "9686077a-115a-4905-9d83-a823336e9781", "id": "77476f68-6dd1-452f-ac48-4a120bb0d53b", "domain": "meta.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:41.048Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074956}, "id": 38138436, "type": "log", "namespace": 2, "title": "User:153.131.213.26", "title_url": "https://meta.wikimedia.org/wiki/User:153.131.213.26", "comment": "[[m:Special:MyLanguage/NOP|Open proxy]]: See the [[m:WM:OP/H|help page]] if you are affected", "timestamp": 1768734940, "user": "XXBlackburnXx", "bot": true, "log_id": 63892615, "log_type": "gblblock", "log_action": "gblock", "log_params": {"expiry": "20260125111540", "flags": []}, "log_action_comment": "XXBlackburnXx globally blocked 153.131.213.26 with an expiration time of 2026-01-25T11:15:40 (account creation disabled): [[m:Special:MyLanguage/NOP|Open proxy]]: See the [[m:WM:OP/H|help page]] if you are affected", "server_url": "https://meta.wikimedia.org", "server_name": "meta.wikimedia.org", "server_script_path": "/w", "wiki": "metawiki", "parsedcomment": "<a href=\"https://meta.wikimedia.org/wiki/Special:MyLanguage/NOP\" class=\"extiw\" title=\"m:Special:MyLanguage/NOP\">Open proxy</a>: See the <a href=\"https://meta.wikimedia.org/wiki/WM:OP/H\" class=\"extiw\" title=\"m:WM:OP/H\">help page</a> if you are affected"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |{"$schema": "/mediawiki/recentchange/1.0.0", "meta": {"uri": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "request_id": "be407ee2-4343-47c7-a7d5-c054317acad8", "id": "831cf9c1-cf94-43e8-b8f1-e7b93b3ef43b", "domain": "commons.wikimedia.org", "stream": "mediawiki.recentchange", "dt": "2026-01-18T11:15:41.035Z", "topic": "codfw.mediawiki.recentchange", "partition": 0, "offset": 1905074957}, "id": 3159709485, "type": "categorize", "namespace": 14, "title": "Category:Files from the United States Army uploaded by PantheraLeo1359531", "title_url": "https://commons.wikimedia.org/wiki/Category:Files_from_the_United_States_Army_uploaded_by_PantheraLeo1359531", "comment": "[[:File:2018 FEMA PuertoRico 20QKF3803 RGB.tif]] added to category", "timestamp": 1768734940, "user": "PantheraLeo1359531", "bot": false, "notify_url": "https://commons.wikimedia.org/w/index.php?diff=1149247071&oldid=1098680096&rcid=3159709485", "server_url": "https://commons.wikimedia.org", "server_name": "commons.wikimedia.org", "server_script_path": "/w", "wiki": "commonswiki", "parsedcomment": "<a href=\"/wiki/File:2018_FEMA_PuertoRico_20QKF3803_RGB.tif\" title=\"File:2018 FEMA PuertoRico 20QKF3803 RGB.tif\">File:2018 FEMA PuertoRico 20QKF3803 RGB.tif</a> added to category"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import get_json_object, count, desc

parsed = out.select(
    get_json_object(col("value"), "$.wiki").alias("wiki"),
    get_json_object(col("value"), "$.type").alias("type")
)

by_wiki = parsed.groupBy("wiki").agg(count("*").alias("cnt")).orderBy(desc("cnt"))

q2 = by_wiki.writeStream \
    .format("console") \
    .outputMode("complete") \
    .option("truncate", "false") \
    .start()
# Out:
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +------------+---+
# |wiki        |cnt|
# +------------+---+
# |commonswiki |149|
# |wikidatawiki|12 |
# |frwiki      |6  |
# |viwiki      |5  |
# |ruwiki      |4  |
# |cawikisource|3  |
# |brwikisource|3  |
# |metawiki    |3  |
# |hawiki      |2  |
# |arwiki      |2  |
# |hewiki      |2  |
# |enwiki      |1  |
# |sqwiki      |1  |
# |itwiki      |1  |
# |tawiki      |1  |
# |dewiki      |1  |
# |eswiki      |1  |
# |afwiki      |1  |
# |kowiki      |1  |
# |rowiki      |1  |
# +------------+---+

# %%
q.stop()
q2.stop()
